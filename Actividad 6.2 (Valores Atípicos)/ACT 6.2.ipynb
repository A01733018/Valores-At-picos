# %%
#Importamos las librerias pandas, numpy y matplotlib respectivamente
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#Carga desde un archivo .csv sin indice
data= pd.read_csv('listings.csv') 

data.head(2)
# Out:
#        id                          listing_url       scrape_id last_scraped  \
# 0  538175  https://www.airbnb.com/rooms/538175  20250619031327   2025-06-19
# 1  541221  https://www.airbnb.com/rooms/541221  20250619031327   2025-06-19
#
#         source                                 name  \
# 0  city scrape  Loft with garden on Naviglio Grande
# 1  city scrape  2 rooms apartment in downtown Milan
#
#                                          description  \
# 0  gorgeous loft with garden. Very quiet and comf...
# 1                                                NaN
#
#                                neighborhood_overview  \
# 0  Neighborhood made by artists, designers, pubs,...
# 1  The apartment is close to Ticinese going out a...
#
#                                          picture_url  host_id  ...  \
# 0  https://a0.muscache.com/pictures/6527563/6060f...  2643876  ...
# 1  https://a0.muscache.com/pictures/7108899/66d9b...  1442498  ...
#
#   review_scores_communication review_scores_location review_scores_value  \
# 0                        4.56                   4.25                4.22
# 1                        4.64                   4.50                3.93
#
#               license instant_bookable calculated_host_listings_count  \
# 0  IT015146C2XCMAQN43                f                              1
# 1  IT015146C2GRLPV2TY                f                              1
#
#   calculated_host_listings_count_entire_homes  \
# 0                                           1
# 1                                           1
#
#   calculated_host_listings_count_private_rooms  \
# 0                                            0
# 1                                            0
#
#   calculated_host_listings_count_shared_rooms reviews_per_month
# 0                                           0              0.06
# 1                                           0              0.13
#
# [2 rows x 79 columns]

# %%
data1 = data.copy()

# %%
#Sustituir valores nulos por un string en  concreto 
#description
data1["description"] =data1["description"].fillna("No description available")

#Neighborhood overview
data1["neighborhood_overview"] =data1["neighborhood_overview"].fillna("No description available")

#Host Location 
data1["host_location"] =data1["host_location"].fillna("Milan, Italy")

#host about 
data1["host_about"] =data1["host_about"].fillna("No description available")

#response time 
data1["host_response_time"] =data1["host_response_time"].fillna("N/A")

#response rate 
data1["host_response_rate"] =data1["host_response_rate"].fillna("N/A")

#response time 
data1["host_acceptance_rate"] =data1["host_acceptance_rate"].fillna("N/A")

#response time 
data1["host_is_superhost"] =data1["host_is_superhost"].fillna("f")

#host neighbourhood
data1["host_neighbourhood"] =data1["host_neighbourhood"].fillna("Not defined")

#neighbourhood
data1["neighbourhood"] =data1["neighbourhood"].fillna("Milan, Lombardy, Italy")


#cleansed
data1["neighbourhood_group_cleansed"] =data1["neighbourhood_group_cleansed"].fillna("Not defined")

#calendar updated
data1["calendar_updated"] =data1["calendar_updated"].fillna("No")

#availability  
data1["has_availability"] =data1["has_availability"].fillna("f")

#first review
data1["first_review"] =data1["first_review"].fillna("No date")

#last review
data1["last_review"] =data1["last_review"].fillna("No date")

#license
data1["license"] =data1["license"].fillna("Not included")

# %%
#bathroom
data1["bathrooms"]= data1["bathrooms"].fillna(1) 
data1.head(5)

#bathroom
data1["bathrooms_text"]= data1["bathrooms_text"].fillna(1) 
data1.head(5)

#bedrooms 
data1["bedrooms"]= data1["bedrooms"].fillna(1) 
data1.head(5)


#beds
data1["beds"]= data1["beds"].fillna(1) 
data1.head(5)

#revenue 365 
data1["estimated_revenue_l365d"]= data1["estimated_revenue_l365d"].fillna(0) 
data1.head(5)

#review score 
data1["review_scores_rating"]= data1["review_scores_rating"].fillna(0) 
data1.head(5)

#review score accuracy 
data1["review_scores_accuracy"]= data1["review_scores_accuracy"].fillna(0) 
data1.head(5)

#review score cleanliness
data1["review_scores_cleanliness"]= data1["review_scores_cleanliness"].fillna(0) 
data1.head(5)

#review score check-inn
data1["review_scores_checkin"]= data1["review_scores_checkin"].fillna(0) 
data1.head(5)

#review score communication
data1["review_scores_communication"]= data1["review_scores_communication"].fillna(0) 
data1.head(5)

#review score location
data1["review_scores_location"]= data1["review_scores_location"].fillna(0) 
data1.head(5)

#review score location
data1["review_scores_value"]= data1["review_scores_value"].fillna(0) 
data1.head(5)

#review scores per month 
data1["reviews_per_month"]= data1["reviews_per_month"].fillna(0) 
data1.head(5)
# Out:
#        id                          listing_url       scrape_id last_scraped  \
# 0  538175  https://www.airbnb.com/rooms/538175  20250619031327   2025-06-19
# 1  541221  https://www.airbnb.com/rooms/541221  20250619031327   2025-06-19
# 2  541668  https://www.airbnb.com/rooms/541668  20250619031327   2025-06-19
# 3  544809  https://www.airbnb.com/rooms/544809  20250619031327   2025-06-19
# 4  553285  https://www.airbnb.com/rooms/553285  20250619031327   2025-06-19
#
#         source                                        name  \
# 0  city scrape         Loft with garden on Naviglio Grande
# 1  city scrape         2 rooms apartment in downtown Milan
# 2  city scrape  Two-rooms Apartment | 50 meters from Metro
# 3  city scrape          2 km DUOMO wifi aircon PortaRomana
# 4  city scrape    Milano Central Luxury - 3 BDR / 7 Guests
#
#                                          description  \
# 0  gorgeous loft with garden. Very quiet and comf...
# 1                           No description available
# 2  Two-room apartment 50 meters away from the Yel...
# 3  perfect for STUDENTS and YOUNG TURISTS 10 mins...
# 4  A stylish and cozy apartment, beautifully furn...
#
#                                neighborhood_overview  \
# 0  Neighborhood made by artists, designers, pubs,...
# 1  The apartment is close to Ticinese going out a...
# 2  Located on the south-eastern of Milan, the Bre...
# 3  extremily reserved, not intrusive. all the apt...
# 4  The Central Luxury apartment, is located just ...
#
#                                          picture_url  host_id  ...  \
# 0  https://a0.muscache.com/pictures/6527563/6060f...  2643876  ...
# 1  https://a0.muscache.com/pictures/7108899/66d9b...  1442498  ...
# 2  https://a0.muscache.com/pictures/miso/Hosting-...  2022842  ...
# 3  https://a0.muscache.com/pictures/11551732/7b0b...  2452841  ...
# 4  https://a0.muscache.com/pictures/miso/Hosting-...  2718914  ...
#
#   review_scores_communication review_scores_location review_scores_value  \
# 0                        4.56                   4.25                4.22
# 1                        4.64                   4.50                3.93
# 2                        4.94                   4.64                4.94
# 3                        4.67                   4.71                4.42
# 4                        4.89                   4.76                4.71
#
#               license instant_bookable calculated_host_listings_count  \
# 0  IT015146C2XCMAQN43                f                              1
# 1  IT015146C2GRLPV2TY                f                              1
# 2  IT015146C2W99LAEKO                f                              1
# 3  IT015146C22ZO8W2CJ                f                              3
# 4  IT015146B4CCMWJAB7                t                             27
#
#   calculated_host_listings_count_entire_homes  \
# 0                                           1
# 1                                           1
# 2                                           1
# 3                                           3
# 4                                          27
#
#   calculated_host_listings_count_private_rooms  \
# 0                                            0
# 1                                            0
# 2                                            0
# 3                                            0
# 4                                            0
#
#   calculated_host_listings_count_shared_rooms reviews_per_month
# 0                                           0              0.06
# 1                                           0              0.13
# 2                                           0              0.41
# 3                                           0              0.93
# 4                                           0              0.91
#
# [5 rows x 79 columns]

# %%
#Sustituir valores nulos por valores no nulos hacia adelante forward fill" ("ffill")

data1["price"] =data1["price"].fillna(method="ffill")
# Out:
# C:\Users\dorop\AppData\Local\Temp\ipykernel_3600\1705301329.py:3: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data1["price"] =data1["price"].fillna(method="ffill")

# %%
#Identificar valores nulos por columna
valores_nulos=data1.isnull().sum()
pd.set_option("display.max_rows", None)       # Todas las filas
valores_nulos
# Out:
# id                                              0
# listing_url                                     0
# scrape_id                                       0
# last_scraped                                    0
# source                                          0
# name                                            0
# description                                     0
# neighborhood_overview                           0
# picture_url                                     0
# host_id                                         0
# host_url                                        0
# host_name                                       0
# host_since                                      0
# host_location                                   0
# host_about                                      0
# host_response_time                              0
# host_response_rate                              0
# host_acceptance_rate                            0
# host_is_superhost                               0
# host_thumbnail_url                              0
# host_picture_url                                0
# host_neighbourhood                              0
# host_listings_count                             0
# host_total_listings_count                       0
# host_verifications                              0
# host_has_profile_pic                            0
# host_identity_verified                          0
# neighbourhood                                   0
# neighbourhood_cleansed                          0
# neighbourhood_group_cleansed                    0
# latitude                                        0
# longitude                                       0
# property_type                                   0
# room_type                                       0
# accommodates                                    0
# bathrooms                                       0
# bathrooms_text                                  0
# bedrooms                                        0
# beds                                            0
# amenities                                       0
# price                                           0
# minimum_nights                                  0
# maximum_nights                                  0
# minimum_minimum_nights                          0
# maximum_minimum_nights                          0
# minimum_maximum_nights                          0
# maximum_maximum_nights                          0
# minimum_nights_avg_ntm                          0
# maximum_nights_avg_ntm                          0
# calendar_updated                                0
# has_availability                                0
# availability_30                                 0
# availability_60                                 0
# availability_90                                 0
# availability_365                                0
# calendar_last_scraped                           0
# number_of_reviews                               0
# number_of_reviews_ltm                           0
# number_of_reviews_l30d                          0
# availability_eoy                                0
# number_of_reviews_ly                            0
# estimated_occupancy_l365d                       0
# estimated_revenue_l365d                         0
# first_review                                    0
# last_review                                     0
# review_scores_rating                            0
# review_scores_accuracy                          0
# review_scores_cleanliness                       0
# review_scores_checkin                           0
# review_scores_communication                     0
# review_scores_location                          0
# review_scores_value                             0
# license                                         0
# instant_bookable                                0
# calculated_host_listings_count                  0
# calculated_host_listings_count_entire_homes     0
# calculated_host_listings_count_private_rooms    0
# calculated_host_listings_count_shared_rooms     0
# reviews_per_month                               0
# dtype: int64

# %%
cuantitativas= data1.select_dtypes(include=["number"])
cualitativas = data1.select_dtypes(include=["object", "category"])

# %%
#Realizamos diagrama de caja o bigote de cada columna del dataframe
fig = plt.figure(figsize =(15, 8))
cuantitativas.plot(kind='box', vert=False)
plt.title("Valores Atípicos del Dataframe")
plt.show() #dibujamos el diagrama

# %%
#Método aplicando desviación estandar. Encuentro los valores extremos
y=cuantitativas
Limite_Superior= y.mean() + 3*y.std()
Limite_Inferior= y.mean() - 3*y.std()
print("Limite superior permitido", Limite_Superior)
print("Limite inferior permitido", Limite_Inferior)
# Out:
# Limite superior permitido id                                              2.381514e+18
# scrape_id                                       2.025062e+13
# host_id                                         8.901971e+08
# host_listings_count                             3.626149e+02
# host_total_listings_count                       5.455489e+02
# latitude                                        4.553343e+01
# longitude                                       9.276383e+00
# accommodates                                    8.072466e+00
# bathrooms                                       2.509207e+00
# bedrooms                                        3.264894e+00
# beds                                            5.157346e+00
# minimum_nights                                  7.520265e+01
# maximum_nights                                  1.544018e+03
# minimum_minimum_nights                          7.228339e+01
# maximum_minimum_nights                          7.754263e+01
# minimum_maximum_nights                          1.849561e+03
# maximum_maximum_nights                          1.931174e+03
# minimum_nights_avg_ntm                          7.457000e+01
# maximum_nights_avg_ntm                          1.847240e+03
# availability_30                                 4.399047e+01
# availability_60                                 9.186833e+01
# availability_90                                 1.381904e+02
# availability_365                                5.318948e+02
# number_of_reviews                               2.994528e+02
# number_of_reviews_ltm                           7.522404e+01
# number_of_reviews_l30d                          8.269366e+00
# availability_eoy                                3.112593e+02
# number_of_reviews_ly                            7.378852e+01
# estimated_occupancy_l365d                       3.371672e+02
# estimated_revenue_l365d                         6.970223e+04
# review_scores_rating                            9.195661e+00
# review_scores_accuracy                          9.275865e+00
# review_scores_cleanliness                       9.222074e+00
# review_scores_checkin                           9.300012e+00
# review_scores_communication                     9.344762e+00
# review_scores_location                          9.188093e+00
# review_scores_value                             8.997888e+00
# calculated_host_listings_count                  3.085719e+02
# calculated_host_listings_count_entire_homes     3.051037e+02
# calculated_host_listings_count_private_rooms    4.034468e+01
# calculated_host_listings_count_shared_rooms     1.274318e+00
# reviews_per_month                               7.310786e+00
# dtype: float64
# Limite inferior permitido id                                             -7.920227e+17
# scrape_id                                       2.025062e+13
# host_id                                        -4.460570e+08
# host_listings_count                            -2.701565e+02
# host_total_listings_count                      -4.203640e+02
# latitude                                        4.540980e+01
# longitude                                       9.099241e+00
# accommodates                                   -1.401126e+00
# bathrooms                                      -2.064120e-01
# bedrooms                                       -8.134302e-01
# beds                                           -1.559830e+00
# minimum_nights                                 -5.865864e+01
# maximum_nights                                 -7.989129e+02
# minimum_minimum_nights                         -5.672172e+01
# maximum_minimum_nights                         -5.880882e+01
# minimum_maximum_nights                         -9.059518e+02
# maximum_maximum_nights                         -8.305008e+02
# minimum_nights_avg_ntm                         -5.766271e+01
# maximum_nights_avg_ntm                         -8.343725e+02
# availability_30                                -1.727121e+01
# availability_60                                -2.760090e+01
# availability_90                                -3.571465e+01
# availability_365                               -1.585621e+02
# number_of_reviews                              -2.165527e+02
# number_of_reviews_ltm                          -4.964010e+01
# number_of_reviews_l30d                         -5.507077e+00
# availability_eoy                               -7.767794e+01
# number_of_reviews_ly                           -5.093093e+01
# estimated_occupancy_l365d                      -1.931529e+02
# estimated_revenue_l365d                        -5.152032e+04
# review_scores_rating                           -1.213100e+00
# review_scores_accuracy                         -1.199490e+00
# review_scores_cleanliness                      -1.212285e+00
# review_scores_checkin                          -1.209686e+00
# review_scores_communication                    -1.211923e+00
# review_scores_location                         -1.173410e+00
# review_scores_value                            -1.211677e+00
# calculated_host_listings_count                 -2.334121e+02
# calculated_host_listings_count_entire_homes    -2.341908e+02
# calculated_host_listings_count_private_rooms   -3.618550e+01
# calculated_host_listings_count_shared_rooms    -1.192242e+00
# reviews_per_month                              -4.309488e+00
# dtype: float64

# %%
#Obtenemos datos y los outliers se convierten en nulos en el DataFrame
data3= cuantitativas[(y<=Limite_Superior)&(y>=Limite_Inferior)]
data3.head(1)
# Out:
#        id       scrape_id  host_id  host_listings_count  \
# 0  538175  20250619031327  2643876                  2.0
#
#    host_total_listings_count  latitude  longitude  accommodates  bathrooms  \
# 0                        3.0   45.4462    9.15515           3.0        1.0
#
#    bedrooms  ...  review_scores_cleanliness  review_scores_checkin  \
# 0       1.0  ...                        4.0                   4.22
#
#    review_scores_communication  review_scores_location  review_scores_value  \
# 0                         4.56                    4.25                 4.22
#
#    calculated_host_listings_count  \
# 0                             1.0
#
#    calculated_host_listings_count_entire_homes  \
# 0                                          1.0
#
#    calculated_host_listings_count_private_rooms  \
# 0                                           0.0
#
#    calculated_host_listings_count_shared_rooms  reviews_per_month
# 0                                          0.0               0.06
#
# [1 rows x 42 columns]

# %%
#Corroboramos valores nulos del dataframe4
valores_nulos=data3.isnull().sum()
valores_nulos
# Out:
# id                                                0
# scrape_id                                         0
# host_id                                           0
# host_listings_count                             863
# host_total_listings_count                       822
# latitude                                         36
# longitude                                       112
# accommodates                                    166
# bathrooms                                       288
# bedrooms                                        237
# beds                                            292
# minimum_nights                                  146
# maximum_nights                                    0
# minimum_minimum_nights                          133
# maximum_minimum_nights                          167
# minimum_maximum_nights                            1
# maximum_maximum_nights                            2
# minimum_nights_avg_ntm                          154
# maximum_nights_avg_ntm                            1
# availability_30                                   0
# availability_60                                   0
# availability_90                                   0
# availability_365                                  0
# number_of_reviews                               498
# number_of_reviews_ltm                           524
# number_of_reviews_l30d                          400
# availability_eoy                                  0
# number_of_reviews_ly                            583
# estimated_occupancy_l365d                         0
# estimated_revenue_l365d                         254
# review_scores_rating                              0
# review_scores_accuracy                            0
# review_scores_cleanliness                         0
# review_scores_checkin                             0
# review_scores_communication                       0
# review_scores_location                            0
# review_scores_value                               0
# calculated_host_listings_count                  825
# calculated_host_listings_count_entire_homes     825
# calculated_host_listings_count_private_rooms    312
# calculated_host_listings_count_shared_rooms     235
# reviews_per_month                               407
# dtype: int64

# %%
#Reemplazamos valores atípicos (nulos) del dataframe con "mean"
#Realizamos una copia del dataframe
data_clean=data3.copy()
data_clean=data_clean.fillna(round(data3.mean(),1))
data_clean.head(1)
# Out:
#        id       scrape_id  host_id  host_listings_count  \
# 0  538175  20250619031327  2643876                  2.0
#
#    host_total_listings_count  latitude  longitude  accommodates  bathrooms  \
# 0                        3.0   45.4462    9.15515           3.0        1.0
#
#    bedrooms  ...  review_scores_cleanliness  review_scores_checkin  \
# 0       1.0  ...                        4.0                   4.22
#
#    review_scores_communication  review_scores_location  review_scores_value  \
# 0                         4.56                    4.25                 4.22
#
#    calculated_host_listings_count  \
# 0                             1.0
#
#    calculated_host_listings_count_entire_homes  \
# 0                                          1.0
#
#    calculated_host_listings_count_private_rooms  \
# 0                                           0.0
#
#    calculated_host_listings_count_shared_rooms  reviews_per_month
# 0                                          0.0               0.06
#
# [1 rows x 42 columns]

# %%
#Corroboramos valores nulos del dataframe LIMPIO
valores_nulos=data_clean.isnull().sum()
valores_nulos
# Out:
# id                                              0
# scrape_id                                       0
# host_id                                         0
# host_listings_count                             0
# host_total_listings_count                       0
# latitude                                        0
# longitude                                       0
# accommodates                                    0
# bathrooms                                       0
# bedrooms                                        0
# beds                                            0
# minimum_nights                                  0
# maximum_nights                                  0
# minimum_minimum_nights                          0
# maximum_minimum_nights                          0
# minimum_maximum_nights                          0
# maximum_maximum_nights                          0
# minimum_nights_avg_ntm                          0
# maximum_nights_avg_ntm                          0
# availability_30                                 0
# availability_60                                 0
# availability_90                                 0
# availability_365                                0
# number_of_reviews                               0
# number_of_reviews_ltm                           0
# number_of_reviews_l30d                          0
# availability_eoy                                0
# number_of_reviews_ly                            0
# estimated_occupancy_l365d                       0
# estimated_revenue_l365d                         0
# review_scores_rating                            0
# review_scores_accuracy                          0
# review_scores_cleanliness                       0
# review_scores_checkin                           0
# review_scores_communication                     0
# review_scores_location                          0
# review_scores_value                             0
# calculated_host_listings_count                  0
# calculated_host_listings_count_entire_homes     0
# calculated_host_listings_count_private_rooms    0
# calculated_host_listings_count_shared_rooms     0
# reviews_per_month                               0
# dtype: int64

# %% [markdown]
# **PROCEDIMIENTO "CUANTILES" PARA SUSTITUIR OUTLIERS EN DATAFRAME**

# %%
#Método aplicando Cuartiles. Encuentro cuartiles 0.25 y 0.75
y=cuantitativas

percentile25=y.quantile(0.25) #Q1
percentile75=y.quantile(0.75) #Q3
iqr= percentile75 - percentile25

Limite_Superior_iqr= percentile75 + 1.5*iqr
Limite_Inferior_iqr= percentile25 - 1.5*iqr
print("Limite superior permitido", Limite_Superior_iqr)
print("Limite inferior permitido", Limite_Inferior_iqr)
# Out:
# Limite superior permitido id                                              3.085898e+18
# scrape_id                                       2.025062e+13
# host_id                                         1.084670e+09
# host_listings_count                             8.350000e+01
# host_total_listings_count                       1.095000e+02
# latitude                                        4.553353e+01
# longitude                                       9.268609e+00
# accommodates                                    7.000000e+00
# bathrooms                                       1.000000e+00
# bedrooms                                        1.000000e+00
# beds                                            3.500000e+00
# minimum_nights                                  6.000000e+00
# maximum_nights                                  8.675000e+02
# minimum_minimum_nights                          4.125000e+00
# maximum_minimum_nights                          1.200000e+01
# minimum_maximum_nights                          2.767500e+03
# maximum_maximum_nights                          2.722500e+03
# minimum_nights_avg_ntm                          6.600000e+00
# maximum_nights_avg_ntm                          2.726400e+03
# availability_30                                 4.900000e+01
# availability_60                                 1.010000e+02
# availability_90                                 1.435000e+02
# availability_365                                5.700000e+02
# number_of_reviews                               1.020000e+02
# number_of_reviews_ltm                           4.000000e+01
# number_of_reviews_l30d                          5.000000e+00
# availability_eoy                                3.365000e+02
# number_of_reviews_ly                            3.250000e+01
# estimated_occupancy_l365d                       3.000000e+02
# estimated_revenue_l365d                         2.898000e+04
# review_scores_rating                            5.880000e+00
# review_scores_accuracy                          5.675000e+00
# review_scores_cleanliness                       5.845000e+00
# review_scores_checkin                           5.725000e+00
# review_scores_communication                     5.750000e+00
# review_scores_location                          5.695000e+00
# review_scores_value                             5.835000e+00
# calculated_host_listings_count                  5.350000e+01
# calculated_host_listings_count_entire_homes     4.600000e+01
# calculated_host_listings_count_private_rooms    0.000000e+00
# calculated_host_listings_count_shared_rooms     0.000000e+00
# reviews_per_month                               5.180000e+00
# dtype: float64
# Limite inferior permitido id                                             -1.851539e+18
# scrape_id                                       2.025062e+13
# host_id                                        -6.144001e+08
# host_listings_count                            -4.850000e+01
# host_total_listings_count                      -6.250000e+01
# latitude                                        4.540833e+01
# longitude                                       9.111331e+00
# accommodates                                   -1.000000e+00
# bathrooms                                       1.000000e+00
# bedrooms                                        1.000000e+00
# beds                                           -5.000000e-01
# minimum_nights                                 -2.000000e+00
# maximum_nights                                 -4.725000e+02
# minimum_minimum_nights                         -8.750000e-01
# maximum_minimum_nights                         -4.000000e+00
# minimum_maximum_nights                         -1.612500e+03
# maximum_maximum_nights                         -1.537500e+03
# minimum_nights_avg_ntm                         -2.200000e+00
# maximum_nights_avg_ntm                         -1.544000e+03
# availability_30                                -2.300000e+01
# availability_60                                -3.500000e+01
# availability_90                                -3.650000e+01
# availability_365                               -2.060000e+02
# number_of_reviews                              -5.800000e+01
# number_of_reviews_ltm                          -2.400000e+01
# number_of_reviews_l30d                         -3.000000e+00
# availability_eoy                               -9.950000e+01
# number_of_reviews_ly                           -1.950000e+01
# estimated_occupancy_l365d                      -1.800000e+02
# estimated_revenue_l365d                        -1.738800e+04
# review_scores_rating                            3.400000e+00
# review_scores_accuracy                          3.795000e+00
# review_scores_cleanliness                       3.485000e+00
# review_scores_checkin                           3.765000e+00
# review_scores_communication                     3.750000e+00
# review_scores_location                          3.655000e+00
# review_scores_value                             3.155000e+00
# calculated_host_listings_count                 -3.050000e+01
# calculated_host_listings_count_entire_homes    -2.600000e+01
# calculated_host_listings_count_private_rooms    0.000000e+00
# calculated_host_listings_count_shared_rooms     0.000000e+00
# reviews_per_month                              -2.900000e+00
# dtype: float64

# %%
#Obtenemos datos limpios del Dataframe
data3_iqr= cuantitativas[(y<=Limite_Superior_iqr)&(y>=Limite_Inferior_iqr)]
data3_iqr.head(1)
# Out:
#        id       scrape_id  host_id  host_listings_count  \
# 0  538175  20250619031327  2643876                  2.0
#
#    host_total_listings_count  latitude  longitude  accommodates  bathrooms  \
# 0                        3.0   45.4462    9.15515           3.0        1.0
#
#    bedrooms  ...  review_scores_cleanliness  review_scores_checkin  \
# 0       1.0  ...                        4.0                   4.22
#
#    review_scores_communication  review_scores_location  review_scores_value  \
# 0                         4.56                    4.25                 4.22
#
#    calculated_host_listings_count  \
# 0                             1.0
#
#    calculated_host_listings_count_entire_homes  \
# 0                                          1.0
#
#    calculated_host_listings_count_private_rooms  \
# 0                                           0.0
#
#    calculated_host_listings_count_shared_rooms  reviews_per_month
# 0                                          0.0               0.06
#
# [1 rows x 42 columns]

# %%
#Corroboramos valores nulos del dataframe LIMPIO
valores_nulos=data3_iqr.isnull().sum()
valores_nulos
# Out:
# id                                                 0
# scrape_id                                          0
# host_id                                            0
# host_listings_count                             3558
# host_total_listings_count                       3404
# latitude                                          34
# longitude                                        292
# accommodates                                     428
# bathrooms                                       3340
# bedrooms                                        6113
# beds                                            1603
# minimum_nights                                  4452
# maximum_nights                                  4118
# minimum_minimum_nights                          4408
# maximum_minimum_nights                          4515
# minimum_maximum_nights                             1
# maximum_maximum_nights                             2
# minimum_nights_avg_ntm                          4478
# maximum_nights_avg_ntm                             1
# availability_30                                    0
# availability_60                                    0
# availability_90                                    0
# availability_365                                   0
# number_of_reviews                               2462
# number_of_reviews_ltm                           2198
# number_of_reviews_l30d                          1569
# availability_eoy                                   0
# number_of_reviews_ly                            2735
# estimated_occupancy_l365d                          0
# estimated_revenue_l365d                         1527
# review_scores_rating                            3809
# review_scores_accuracy                          3907
# review_scores_cleanliness                       3792
# review_scores_checkin                           3935
# review_scores_communication                     3860
# review_scores_location                          3721
# review_scores_value                             3857
# calculated_host_listings_count                  3682
# calculated_host_listings_count_entire_homes     3665
# calculated_host_listings_count_private_rooms    4310
# calculated_host_listings_count_shared_rooms      257
# reviews_per_month                               1390
# dtype: int64

# %%
#Reemplazamos valores atípicos (nulos) del dataframe con "mean"
#Realizamos una copia del dataframe
data4_iqr=data3_iqr.copy()
data4_iqr=data4_iqr.fillna(round(data3_iqr.median(),1))
data4_iqr.head(1)
# Out:
#        id       scrape_id  host_id  host_listings_count  \
# 0  538175  20250619031327  2643876                  2.0
#
#    host_total_listings_count  latitude  longitude  accommodates  bathrooms  \
# 0                        3.0   45.4462    9.15515           3.0        1.0
#
#    bedrooms  ...  review_scores_cleanliness  review_scores_checkin  \
# 0       1.0  ...                        4.0                   4.22
#
#    review_scores_communication  review_scores_location  review_scores_value  \
# 0                         4.56                    4.25                 4.22
#
#    calculated_host_listings_count  \
# 0                             1.0
#
#    calculated_host_listings_count_entire_homes  \
# 0                                          1.0
#
#    calculated_host_listings_count_private_rooms  \
# 0                                           0.0
#
#    calculated_host_listings_count_shared_rooms  reviews_per_month
# 0                                          0.0               0.06
#
# [1 rows x 42 columns]

# %%
# Unimos el dataframe cuantitativo limpio con el dataframe cualitativo

Datos_limpios = pd.concat([cualitativas, data4_iqr], axis=1)
Datos_limpios.head(1)
# Out:
#                            listing_url last_scraped       source  \
# 0  https://www.airbnb.com/rooms/538175   2025-06-19  city scrape
#
#                                   name  \
# 0  Loft with garden on Naviglio Grande
#
#                                          description  \
# 0  gorgeous loft with garden. Very quiet and comf...
#
#                                neighborhood_overview  \
# 0  Neighborhood made by artists, designers, pubs,...
#
#                                          picture_url  \
# 0  https://a0.muscache.com/pictures/6527563/6060f...
#
#                                     host_url host_name  host_since  ...  \
# 0  https://www.airbnb.com/users/show/2643876   Barbara  2012-06-15  ...
#
#   review_scores_cleanliness review_scores_checkin review_scores_communication  \
# 0                       4.0                  4.22                        4.56
#
#   review_scores_location review_scores_value calculated_host_listings_count  \
# 0                   4.25                4.22                            1.0
#
#   calculated_host_listings_count_entire_homes  \
# 0                                         1.0
#
#   calculated_host_listings_count_private_rooms  \
# 0                                          0.0
#
#   calculated_host_listings_count_shared_rooms reviews_per_month
# 0                                         0.0              0.06
#
# [1 rows x 79 columns]

# %%
#Corroboramos valores nulos del dataframe LIMPIO
valores_nulos=Datos_limpios.isnull().sum()
valores_nulos
# Out:
# listing_url                                     0
# last_scraped                                    0
# source                                          0
# name                                            0
# description                                     0
# neighborhood_overview                           0
# picture_url                                     0
# host_url                                        0
# host_name                                       0
# host_since                                      0
# host_location                                   0
# host_about                                      0
# host_response_time                              0
# host_response_rate                              0
# host_acceptance_rate                            0
# host_is_superhost                               0
# host_thumbnail_url                              0
# host_picture_url                                0
# host_neighbourhood                              0
# host_verifications                              0
# host_has_profile_pic                            0
# host_identity_verified                          0
# neighbourhood                                   0
# neighbourhood_cleansed                          0
# neighbourhood_group_cleansed                    0
# property_type                                   0
# room_type                                       0
# bathrooms_text                                  0
# amenities                                       0
# price                                           0
# calendar_updated                                0
# has_availability                                0
# calendar_last_scraped                           0
# first_review                                    0
# last_review                                     0
# license                                         0
# instant_bookable                                0
# id                                              0
# scrape_id                                       0
# host_id                                         0
# host_listings_count                             0
# host_total_listings_count                       0
# latitude                                        0
# longitude                                       0
# accommodates                                    0
# bathrooms                                       0
# bedrooms                                        0
# beds                                            0
# minimum_nights                                  0
# maximum_nights                                  0
# minimum_minimum_nights                          0
# maximum_minimum_nights                          0
# minimum_maximum_nights                          0
# maximum_maximum_nights                          0
# minimum_nights_avg_ntm                          0
# maximum_nights_avg_ntm                          0
# availability_30                                 0
# availability_60                                 0
# availability_90                                 0
# availability_365                                0
# number_of_reviews                               0
# number_of_reviews_ltm                           0
# number_of_reviews_l30d                          0
# availability_eoy                                0
# number_of_reviews_ly                            0
# estimated_occupancy_l365d                       0
# estimated_revenue_l365d                         0
# review_scores_rating                            0
# review_scores_accuracy                          0
# review_scores_cleanliness                       0
# review_scores_checkin                           0
# review_scores_communication                     0
# review_scores_location                          0
# review_scores_value                             0
# calculated_host_listings_count                  0
# calculated_host_listings_count_entire_homes     0
# calculated_host_listings_count_private_rooms    0
# calculated_host_listings_count_shared_rooms     0
# reviews_per_month                               0
# dtype: int64

# %%
#Convertir DataFrame a CSV
Datos_limpios.to_csv("Act6.2.csv")
